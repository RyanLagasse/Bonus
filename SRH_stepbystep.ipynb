# %%
import os
from PIL import Image
import numpy as np
from scipy.spatial import KDTree

# Load images
folder_path = "outputs"
files = os.listdir(folder_path)
images = [Image.open(os.path.join(folder_path, file)) for file in files]

# %%
# show images using matplotlib
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, len(images))
for ax, image in zip(axes, images):
    ax.imshow(image)
    ax.axis('off')
plt.show()

# %%
# 1. Feature Detection and Matching
def detect_features(image):
    # Implement your feature detection algorithm here
    # For example, you could use the SIFT algorithm
    # Return a list of (x, y, feature_vector) tuples representing detected features
    pass

def match_features(features1, features2):
    # Implement your feature matching algorithm here
    # For example, you could use Brute-Force Matcher or FLANN
    # Return a list of (idx1, idx2) tuples representing matched feature pairs
    pass

# Test feature detection and matching
for i in range(len(images)):
    for j in range(i+1, len(images)):
        features1 = detect_features(images[i])
        features2 = detect_features(images[j])
        matches = match_features(features1, features2)
        print(f"Matches between image {i} and {j}: {len(matches)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 30
#      28 features2 = detect_features(images[j])
#      29 matches = match_features(features1, features2)
# ---> 30 print(f"Matches between image {i} and {j}: {len(matches)}")
#
# TypeError: object of type 'NoneType' has no len()
